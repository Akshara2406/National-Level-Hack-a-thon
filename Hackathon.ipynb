# %% [markdown]
# ## National Level Online Hack-a-thon on Sustainable Energy

# %%
import atoti as tt
# Out:
# Welcome to atoti 0.6.3!
#
#     By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
#     Browse the official documentation at https://docs.atoti.io.
#     Join the community at https://www.atoti.io/register.
#
#     atoti collects telemetry data, which is used to help understand how to improve the product.
#     If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
#     You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %%
session = tt.create_session()

# %%
df = session.read_csv('./data/BO5341_IoTData.csv',keys=["X"])

# %%
df.head()
# Out:
#   Product_Qty_Unit    Product_ID  Production_Start_Time  \
# X
# 1               KG  Product_0407                  40656
# 2               KG  Product_0407                 201026
# 3               KG  Product_0407                  81616
# 4               KG  Product_0407                 202857
# 5               KG  Product_0407                  81630
#
#    Output_QualityParameter1  Material_ID   Product_Name  \
# X
# 1                380.000000         1234  Tide Plus Oxi
# 2                391.082110         1234  Tide Plus Oxi
# 3                386.162120         1234  Tide Plus Oxi
# 4                392.747275         1234  Tide Plus Oxi
# 5                386.824660         1234  Tide Plus Oxi
#
#    Output_QualityParameter2  Output_QualityParameter3  \
# X
# 1               15625.00000                39000.0000
# 2               14202.98200                36257.6125
# 3               16356.86700                39566.6110
# ...

# %%
cube = session.create_cube(df)

# %%
h = cube.hierarchies
h
# Out:
# Hierarchies()

# %%
l = cube.levels

# %%
m = cube.measures
m
# Out:
# Measures()

# %%
cube.query(m["Order_Quantity.SUM"])
# Out:
#   Order_Quantity.SUM
# 0          4,983,152

# %%
cube.query(m["Order_Quantity.SUM"], levels=[l["X"]])
# Out:
#      Order_Quantity.SUM
# X
# 1                 3,800
# 2                 3,800
# 3                 3,800
# 4                 3,800
# 5                 3,800
# ...                 ...
# 8711              5,600
# 8851              5,600
# 8861              5,600
# 8881              5,600
# 8891              5,600
#
# [1000 rows x 1 columns]

# %%
cube.query(
    m["Order_Quantity.SUM"],
    condition=l["X"] == "1",
)
# Out:
#   Order_Quantity.SUM
# 0              3,800

# %%
cube.query(m["Order_Quantity.SUM"], levels=[l["Manufacturing_StartDate"], l["Detergent_Quality"]])
# Out:
#                                           Order_Quantity.SUM
# Manufacturing_StartDate Detergent_Quality
# 01-02-2014 00:00        Good                          16,800
# 01-03-2014 00:00        Bad                            5,040
#                         Good                           5,040
# 01-05-2014 00:00        Bad                           28,000
#                         Good                          15,600
# ...                                                      ...
# 29-12-2013 00:00        Good                          11,200
# 30-01-2014 00:00        Bad                            5,600
# 30-04-2014 00:00        Good                           5,000
# 30-05-2014 00:00        Good                          30,000
# 31-12-2014 00:00        Good                          35,000
#
# [284 rows x 1 columns]

# %%
cube.query(
    m["Order_Quantity.SUM"],
    levels=[l["Manufacturing_StartDate"], l["Detergent_Quality"]],
    condition=l["X"] == "1",
)
# Out:
#                                           Order_Quantity.SUM
# Manufacturing_StartDate Detergent_Quality
# 20-02-2014 00:00        Good                           3,800

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/BO5341_IoTData.csv')

# %%
df.shape
# Out:
# (1000, 122)

# %%
df.head()
# Out:
#    X Product_Qty_Unit    Product_ID  Production_Start_Time  \
# 0  1               KG  Product_0407                  40656
# 1  2               KG  Product_0407                 201026
# 2  3               KG  Product_0407                  81616
# 3  4               KG  Product_0407                 202857
# 4  5               KG  Product_0407                  81630
#
#    Output_QualityParameter1  Material_ID   Product_Name  \
# 0                380.000000         1234  Tide Plus Oxi
# 1                391.082110         1234  Tide Plus Oxi
# 2                386.162120         1234  Tide Plus Oxi
# 3                392.747275         1234  Tide Plus Oxi
# 4                386.824660         1234  Tide Plus Oxi
#
#    Output_QualityParameter2  Output_QualityParameter3  \
# 0               15625.00000                39000.0000
# 1               14202.98200                36257.6125
# 2               16356.86700                39566.6110
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
#Finding the class distribution of 'Detergent Quality' column
df['Detergent_Quality'].describe()
# Out:
# count     1000
# unique       2
# top       Good
# freq       775
# Name: Detergent_Quality, dtype: object

# %%
#Doing a train test split based on index
traindata = df[0:900]
testdata = df[900:]
print('Data for Modeling: ' + str(traindata.shape))
print('Unseen Test Data For Predictions: ' + str(testdata.shape))
# Out:
# Data for Modeling: (900, 122)
# Unseen Test Data For Predictions: (100, 122)

# %%
# Import Classification modules from pycaret
from pycaret.classification import *

# %%
target = 'Detergent_Quality'
data = traindata

# %%
exp_clf = setup(data=data, target = target,fix_imbalance=True, feature_selection=True, session_id=100)
# Out:
# <style type="text/css">
# #T_fd3ce_row5_col1, #T_fd3ce_row44_col1, #T_fd3ce_row52_col1, #T_fd3ce_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fd3ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd3ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd3ce_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_fd3ce_row0_col1" class="data row0 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_fd3ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd3ce_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fd3ce_row1_col1" class="data row1 col1" >Detergent_Quality</td>
#     </tr>
#     <tr>
#       <th id="T_fd3ce_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Determine the best model among different models based on metrics
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_f10c9_ th {
#   text-align: left;
# }
# ...

# %%
regression_results = pull()
print(regression_results)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ada                  Ada Boost Classifier    0.9952  0.9941  0.9960  0.9980
# lightgbm  Light Gradient Boosting Machine    0.9889  0.9954  0.9919  0.9940
# gbc          Gradient Boosting Classifier    0.9873  0.9962  0.9878  0.9960
# dt               Decision Tree Classifier    0.9778  0.9645  0.9878  0.9840
# rf               Random Forest Classifier    0.9475  0.9832  0.9696  0.9645
# et                 Extra Trees Classifier    0.8823  0.9380  0.9168  0.9343
# ridge                    Ridge Classifier    0.7838  0.0000  0.7989  0.9141
# qda       Quadratic Discriminant Analysis    0.7823  0.5164  0.9878  0.7880
# lda          Linear Discriminant Analysis    0.7647  0.8143  0.7845  0.9028
# nb                            Naive Bayes    0.7615  0.8912  0.7135  0.9758
# knn                K Neighbors Classifier    0.7361  0.8127  0.7257  0.9198
# ...

# %%
df1 = pd.DataFrame(regression_results)

# %%
df1.iloc[: , 0:]
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ada                  Ada Boost Classifier    0.9952  0.9941  0.9960  0.9980
# lightgbm  Light Gradient Boosting Machine    0.9889  0.9954  0.9919  0.9940
# gbc          Gradient Boosting Classifier    0.9873  0.9962  0.9878  0.9960
# dt               Decision Tree Classifier    0.9778  0.9645  0.9878  0.9840
# rf               Random Forest Classifier    0.9475  0.9832  0.9696  0.9645
# et                 Extra Trees Classifier    0.8823  0.9380  0.9168  0.9343
# ridge                    Ridge Classifier    0.7838  0.0000  0.7989  0.9141
# qda       Quadratic Discriminant Analysis    0.7823  0.5164  0.9878  0.7880
# lda          Linear Discriminant Analysis    0.7647  0.8143  0.7845  0.9028
# nb                            Naive Bayes    0.7615  0.8912  0.7135  0.9758
# knn                K Neighbors Classifier    0.7361  0.8127  0.7257  0.9198
# ...

# %%
df1.to_csv('./file1.csv')

# %%
df2 = pd.read_csv('./file1.csv')
df2
# Out:
#    Unnamed: 0                            Model  Accuracy     AUC  Recall  \
# 0         ada             Ada Boost Classifier    0.9952  0.9941  0.9960
# 1    lightgbm  Light Gradient Boosting Machine    0.9889  0.9954  0.9919
# 2         gbc     Gradient Boosting Classifier    0.9873  0.9962  0.9878
# 3          dt         Decision Tree Classifier    0.9778  0.9645  0.9878
# 4          rf         Random Forest Classifier    0.9475  0.9832  0.9696
# 5          et           Extra Trees Classifier    0.8823  0.9380  0.9168
# 6       ridge                 Ridge Classifier    0.7838  0.0000  0.7989
# 7         qda  Quadratic Discriminant Analysis    0.7823  0.5164  0.9878
# 8         lda     Linear Discriminant Analysis    0.7647  0.8143  0.7845
# 9          nb                      Naive Bayes    0.7615  0.8912  0.7135
# 10        knn           K Neighbors Classifier    0.7361  0.8127  0.7257
# 11         lr              Logistic Regression    0.6962  0.7490  0.6993
# ...

# %%
df3 = df2.iloc[: , 1:]

# %%
df3
# Out:
#                               Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0              Ada Boost Classifier    0.9952  0.9941  0.9960  0.9980  0.9970
# 1   Light Gradient Boosting Machine    0.9889  0.9954  0.9919  0.9940  0.9929
# 2      Gradient Boosting Classifier    0.9873  0.9962  0.9878  0.9960  0.9918
# 3          Decision Tree Classifier    0.9778  0.9645  0.9878  0.9840  0.9858
# 4          Random Forest Classifier    0.9475  0.9832  0.9696  0.9645  0.9667
# 5            Extra Trees Classifier    0.8823  0.9380  0.9168  0.9343  0.9236
# 6                  Ridge Classifier    0.7838  0.0000  0.7989  0.9141  0.8511
# 7   Quadratic Discriminant Analysis    0.7823  0.5164  0.9878  0.7880  0.8765
# 8      Linear Discriminant Analysis    0.7647  0.8143  0.7845  0.9028  0.8379
# 9                       Naive Bayes    0.7615  0.8912  0.7135  0.9758  0.8224
# 10           K Neighbors Classifier    0.7361  0.8127  0.7257  0.9198  0.8100
# ...

# %%
data = pd.DataFrame({'Model': 0 ,'AUC' : 0,'Accuracy': 0 ,'Recall': 0, 'Prec.': 0 , 'F1': 0 , 'Kappa': 0,'MCC': 0, 'TT (Sec)' : 0},
                                                            index =[0])
# simply concatenate both dataframes
df3 = pd.concat([data, df3]).reset_index(drop = True)
df3.head(5)
# Out:
#                              Model     AUC  Accuracy  Recall  Prec.      F1  \
# 0                                0  0.0000    0.0000  0.0000  0.000  0.0000
# 1             Ada Boost Classifier  0.9941    0.9952  0.9960  0.998  0.9970
# 2  Light Gradient Boosting Machine  0.9954    0.9889  0.9919  0.994  0.9929
# 3     Gradient Boosting Classifier  0.9962    0.9873  0.9878  0.996  0.9918
# 4         Decision Tree Classifier  0.9645    0.9778  0.9878  0.984  0.9858
#
#     Kappa     MCC  TT (Sec)
# 0  0.0000  0.0000     0.000
# 1  0.9858  0.9861     0.367
# 2  0.9669  0.9674     0.521
# 3  0.9630  0.9636     1.143
# 4  0.9344  0.9354     0.084

# %%
df3
# Out:
#                               Model     AUC  Accuracy  Recall   Prec.      F1  \
# 0                                 0  0.0000    0.0000  0.0000  0.0000  0.0000
# 1              Ada Boost Classifier  0.9941    0.9952  0.9960  0.9980  0.9970
# 2   Light Gradient Boosting Machine  0.9954    0.9889  0.9919  0.9940  0.9929
# 3      Gradient Boosting Classifier  0.9962    0.9873  0.9878  0.9960  0.9918
# 4          Decision Tree Classifier  0.9645    0.9778  0.9878  0.9840  0.9858
# 5          Random Forest Classifier  0.9832    0.9475  0.9696  0.9645  0.9667
# 6            Extra Trees Classifier  0.9380    0.8823  0.9168  0.9343  0.9236
# 7                  Ridge Classifier  0.0000    0.7838  0.7989  0.9141  0.8511
# 8   Quadratic Discriminant Analysis  0.5164    0.7823  0.9878  0.7880  0.8765
# 9      Linear Discriminant Analysis  0.8143    0.7647  0.7845  0.9028  0.8379
# 10                      Naive Bayes  0.8912    0.7615  0.7135  0.9758  0.8224
# ...

# %%
df3.to_csv('./file2.csv',index=False)

# %%
df5 = session.read_csv('./file2.csv')

# %%
len(df5)
# Out:
# 15

# %%
df5.head(10)
# Out:
#                              Model     AUC  Accuracy  Recall   Prec.      F1  \
# 0                                0  0.0000    0.0000  0.0000  0.0000  0.0000
# 1             Ada Boost Classifier  0.9941    0.9952  0.9960  0.9980  0.9970
# 2  Light Gradient Boosting Machine  0.9954    0.9889  0.9919  0.9940  0.9929
# 3     Gradient Boosting Classifier  0.9962    0.9873  0.9878  0.9960  0.9918
# 4         Decision Tree Classifier  0.9645    0.9778  0.9878  0.9840  0.9858
# 5         Random Forest Classifier  0.9832    0.9475  0.9696  0.9645  0.9667
# 6           Extra Trees Classifier  0.9380    0.8823  0.9168  0.9343  0.9236
# 7                 Ridge Classifier  0.0000    0.7838  0.7989  0.9141  0.8511
# 8  Quadratic Discriminant Analysis  0.5164    0.7823  0.9878  0.7880  0.8765
# 9     Linear Discriminant Analysis  0.8143    0.7647  0.7845  0.9028  0.8379
#
#     Kappa     MCC  TT (Sec)
# 0  0.0000  0.0000     0.000
# 1  0.9858  0.9861     0.367
# 2  0.9669  0.9674     0.521
# ...

# %%
cube1 = session.create_cube(df5)

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
print(best_model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=100)

# %%
tuned_model = tune_model(estimator=best_model)
# Out:
# <style type="text/css">
# #T_01968_row10_col0, #T_01968_row10_col1, #T_01968_row10_col2, #T_01968_row10_col3, #T_01968_row10_col4, #T_01968_row10_col5, #T_01968_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_01968_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01968_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01968_row0_col0" class="data row0 col0" >0.9841</td>
#       <td id="T_01968_row0_col1" class="data row0 col1" >0.9854</td>
# ...

# %%
regression_results = pull()
print(regression_results)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9841  0.9854  0.9800  1.0000  0.9899  0.9529  0.9539
# 1       0.9841  0.9692  1.0000  0.9804  0.9901  0.9501  0.9513
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.9524  0.9971  0.9592  0.9792  0.9691  0.8657  0.8665
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.9841  1.0000  0.9796  1.0000  0.9897  0.9552  0.9562
# 7       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# Mean    0.9905  0.9952  0.9919  0.9960  0.9939  0.9724  0.9728
# SD      0.0145  0.0097  0.0135  0.0081  0.0094  0.0414  0.0410

# %%
df6 = pd.DataFrame(regression_results)

# %%
df6
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9841  0.9854  0.9800  1.0000  0.9899  0.9529  0.9539
# 1       0.9841  0.9692  1.0000  0.9804  0.9901  0.9501  0.9513
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.9524  0.9971  0.9592  0.9792  0.9691  0.8657  0.8665
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.9841  1.0000  0.9796  1.0000  0.9897  0.9552  0.9562
# 7       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# Mean    0.9905  0.9952  0.9919  0.9960  0.9939  0.9724  0.9728
# SD      0.0145  0.0097  0.0135  0.0081  0.0094  0.0414  0.0410

# %%
df6.to_csv('./file3.csv')

# %%
df7 = pd.read_csv('./file3.csv')
df7
# Out:
#    Unnamed: 0  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0           0    0.9841  0.9854  0.9800  1.0000  0.9899  0.9529  0.9539
# 1           1    0.9841  0.9692  1.0000  0.9804  0.9901  0.9501  0.9513
# 2           2    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3           3    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4           4    0.9524  0.9971  0.9592  0.9792  0.9691  0.8657  0.8665
# 5           5    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6           6    0.9841  1.0000  0.9796  1.0000  0.9897  0.9552  0.9562
# 7           7    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8           8    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9           9    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 10       Mean    0.9905  0.9952  0.9919  0.9960  0.9939  0.9724  0.9728
# 11         SD    0.0145  0.0097  0.0135  0.0081  0.0094  0.0414  0.0410

# %%
df7.columns.values[0] = "Value"

# %%
df7
# Out:
#    Value  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0      0    0.9841  0.9854  0.9800  1.0000  0.9899  0.9529  0.9539
# 1      1    0.9841  0.9692  1.0000  0.9804  0.9901  0.9501  0.9513
# 2      2    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3      3    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4      4    0.9524  0.9971  0.9592  0.9792  0.9691  0.8657  0.8665
# 5      5    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6      6    0.9841  1.0000  0.9796  1.0000  0.9897  0.9552  0.9562
# 7      7    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8      8    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9      9    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 10  Mean    0.9905  0.9952  0.9919  0.9960  0.9939  0.9724  0.9728
# 11    SD    0.0145  0.0097  0.0135  0.0081  0.0094  0.0414  0.0410

# %%
df7.to_csv('./file4.csv',index=False)

# %%
df8 = session.read_csv('./file4.csv')

# %%
len(df8)
# Out:
# 12

# %%
df8.head(10)
# Out:
#    Value  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0      0    0.9841  0.9854  0.9800  1.0000  0.9899  0.9529  0.9539
# 1      1    0.9841  0.9692  1.0000  0.9804  0.9901  0.9501  0.9513
# 2      2    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3      3    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4      4    0.9524  0.9971  0.9592  0.9792  0.9691  0.8657  0.8665
# 5      5    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6      6    0.9841  1.0000  0.9796  1.0000  0.9897  0.9552  0.9562
# 7      7    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8      8    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9      9    1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000

# %%
cube2 = session.create_cube(df8)

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
print(tuned_model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.2,
#                    n_estimators=190, random_state=100)

# %%
final_model = finalize_model(best_model)

# %%
print(final_model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=100)

# %%
predictions = predict_model(final_model, data=testdata)

# %%
predictions.head(10)
# Out:
#         X Product_Qty_Unit    Product_ID  Production_Start_Time  \
# 900  4471               KG  Product_0407                 201026
# 901  8171               KG  Product_0407                 141856
# 902   981               KG  Product_0407                  84821
# 903  8451               KG  Product_0407                 210149
# 904  4410               KG  Product_0407                 202438
# 905  8541               KG  Product_0407                 132941
# 906  4511               KG  Product_0407                 223132
# 907  6281               KG  Product_0407                 230517
# 908  7510               KG  Product_0407                 115145
# 909  3341               KG  Product_0407                 121652
#
#      Output_QualityParameter1  Material_ID   Product_Name  \
# 900                438.011963         1234  Tide Plus Oxi
# 901                438.715816         1234  Tide Plus Oxi
# 902                389.081690         1234  Tide Plus Oxi
# ...

# %%
df11 = predictions

# %%
df11
# Out:
#         X Product_Qty_Unit    Product_ID  Production_Start_Time  \
# 900  4471               KG  Product_0407                 201026
# 901  8171               KG  Product_0407                 141856
# 902   981               KG  Product_0407                  84821
# 903  8451               KG  Product_0407                 210149
# 904  4410               KG  Product_0407                 202438
# ..    ...              ...           ...                    ...
# 995  7311               KG  Product_0407                 163158
# 996  6410               KG  Product_0407                 141056
# 997  7591               KG  Product_0407                  65917
# 998  6671               KG  Product_0407                  45736
# 999  2341               KG  Product_0407                 192056
#
#      Output_QualityParameter1  Material_ID   Product_Name  \
# 900                438.011963         1234  Tide Plus Oxi
# 901                438.715816         1234  Tide Plus Oxi
# ...

# %%
df11.to_csv('./file5.csv',index=False)

# %%
df12 = session.read_csv('./file5.csv')

# %%
cube3 = session.create_cube(df12)

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.link()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to see this link.

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 900 to 999
# Columns: 124 entries, X to Score
# dtypes: float64(86), int64(11), object(27)
# memory usage: 97.0+ KB

# %%
df11.fillna(0)
# Out:
#         X Product_Qty_Unit    Product_ID  Production_Start_Time  \
# 900  4471               KG  Product_0407                 201026
# 901  8171               KG  Product_0407                 141856
# 902   981               KG  Product_0407                  84821
# 903  8451               KG  Product_0407                 210149
# 904  4410               KG  Product_0407                 202438
# ..    ...              ...           ...                    ...
# 995  7311               KG  Product_0407                 163158
# 996  6410               KG  Product_0407                 141056
# 997  7591               KG  Product_0407                  65917
# 998  6671               KG  Product_0407                  45736
# 999  2341               KG  Product_0407                 192056
#
#      Output_QualityParameter1  Material_ID   Product_Name  \
# 900                438.011963         1234  Tide Plus Oxi
# 901                438.715816         1234  Tide Plus Oxi
# ...

# %%
df11.isnull()
# Out:
#          X  Product_Qty_Unit  Product_ID  Production_Start_Time  \
# 900  False             False       False                  False
# 901  False             False       False                  False
# 902  False             False       False                  False
# 903  False             False       False                  False
# 904  False             False       False                  False
# ..     ...               ...         ...                    ...
# 995  False             False       False                  False
# 996  False             False       False                  False
# 997  False             False       False                  False
# 998  False             False       False                  False
# 999  False             False       False                  False
#
#      Output_QualityParameter1  Material_ID  Product_Name  \
# 900                     False        False         False
# 901                     False        False         False
# ...

# %%
df11.replace(np.nan, 0)
# Out:
#         X Product_Qty_Unit    Product_ID  Production_Start_Time  \
# 900  4471               KG  Product_0407                 201026
# 901  8171               KG  Product_0407                 141856
# 902   981               KG  Product_0407                  84821
# 903  8451               KG  Product_0407                 210149
# 904  4410               KG  Product_0407                 202438
# ..    ...              ...           ...                    ...
# 995  7311               KG  Product_0407                 163158
# 996  6410               KG  Product_0407                 141056
# 997  7591               KG  Product_0407                  65917
# 998  6671               KG  Product_0407                  45736
# 999  2341               KG  Product_0407                 192056
#
#      Output_QualityParameter1  Material_ID   Product_Name  \
# 900                438.011963         1234  Tide Plus Oxi
# 901                438.715816         1234  Tide Plus Oxi
# ...

# %%
df11.isnull().sum()
# Out:
# X                           0
# Product_Qty_Unit            0
# Product_ID                  0
# Production_Start_Time       0
# Output_QualityParameter1    0
#                            ..
# Stage5_QP3_High             0
# Stage5_ResourceName         0
# Detergent_Quality           0
# Label                       0
# Score                       0
# Length: 124, dtype: int64
